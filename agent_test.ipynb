# %%
import boto3

session = boto3.Session(profile_name="default", region_name="us-west-2")

# %%
bedrock = session.client("bedrock-runtime")

print(session)
print()

sts = session.client("sts")
identity = sts.get_caller_identity()
print(identity)
# Out:
# Session(region_name='us-west-2')
#
# {'UserId': 'AIDAXB563TTQUDRVBBEHG', 'Account': '485194702049', 'Arn': 'arn:aws:iam::485194702049:user/ilan', 'ResponseMetadata': {'RequestId': '2af072ac-cc52-4d93-86b5-34ac0c89ae05', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '2af072ac-cc52-4d93-86b5-34ac0c89ae05', 'content-type': 'text/xml', 'content-length': '401', 'date': 'Sat, 05 Apr 2025 19:26:30 GMT'}, 'RetryAttempts': 0}}

# %% [markdown]
# # LLM :

# %% [markdown]
# List all foundation models available in Amazon Bedrock
#
# This will print the model IDs of all foundation models

# %%
bedrock = session.client("bedrock")

models = bedrock.list_foundation_models()
for model in models['modelSummaries']:
    print(f"Model ID: {model['modelId']}")
# Out:
# Model ID: amazon.titan-tg1-large
# Model ID: amazon.titan-embed-g1-text-02
# Model ID: amazon.titan-text-lite-v1:0:4k
# Model ID: amazon.titan-text-lite-v1
# Model ID: amazon.titan-text-express-v1:0:8k
# Model ID: amazon.titan-text-express-v1
# Model ID: amazon.nova-pro-v1:0
# Model ID: amazon.nova-lite-v1:0
# Model ID: amazon.nova-micro-v1:0
# Model ID: amazon.titan-embed-text-v1:2:8k
# Model ID: amazon.titan-embed-text-v1
# Model ID: amazon.titan-embed-text-v2:0
# Model ID: amazon.titan-embed-image-v1:0
# Model ID: amazon.titan-embed-image-v1
# Model ID: amazon.titan-image-generator-v1:0
# Model ID: amazon.titan-image-generator-v1
# Model ID: amazon.titan-image-generator-v2:0
# Model ID: amazon.rerank-v1:0
# Model ID: stability.stable-diffusion-xl-v1:0
# Model ID: stability.stable-diffusion-xl-v1
# Model ID: stability.sd3-large-v1:0
# Model ID: stability.sd3-5-large-v1:0
# Model ID: stability.stable-image-core-v1:0
# Model ID: stability.stable-image-core-v1:1
# Model ID: stability.stable-image-ultra-v1:0
# Model ID: stability.stable-image-ultra-v1:1
# Model ID: anthropic.claude-3-5-sonnet-20241022-v2:0:18k
# Model ID: anthropic.claude-3-5-sonnet-20241022-v2:0:51k
# Model ID: anthropic.claude-3-5-sonnet-20241022-v2:0:200k
# Model ID: anthropic.claude-3-5-sonnet-20241022-v2:0
# Model ID: anthropic.claude-3-7-sonnet-20250219-v1:0
# Model ID: anthropic.claude-3-5-haiku-20241022-v1:0
# Model ID: anthropic.claude-instant-v1:2:100k
# Model ID: anthropic.claude-instant-v1
# Model ID: anthropic.claude-v2:0:18k
# Model ID: anthropic.claude-v2:0:100k
# Model ID: anthropic.claude-v2:1:18k
# Model ID: anthropic.claude-v2:1:200k
# Model ID: anthropic.claude-v2:1
# Model ID: anthropic.claude-v2
# Model ID: anthropic.claude-3-sonnet-20240229-v1:0:28k
# Model ID: anthropic.claude-3-sonnet-20240229-v1:0:200k
# Model ID: anthropic.claude-3-sonnet-20240229-v1:0
# Model ID: anthropic.claude-3-haiku-20240307-v1:0:48k
# Model ID: anthropic.claude-3-haiku-20240307-v1:0:200k
# Model ID: anthropic.claude-3-haiku-20240307-v1:0
# Model ID: anthropic.claude-3-opus-20240229-v1:0:12k
# Model ID: anthropic.claude-3-opus-20240229-v1:0:28k
# Model ID: anthropic.claude-3-opus-20240229-v1:0:200k
# Model ID: anthropic.claude-3-opus-20240229-v1:0
# Model ID: anthropic.claude-3-5-sonnet-20240620-v1:0:18k
# Model ID: anthropic.claude-3-5-sonnet-20240620-v1:0:51k
# Model ID: anthropic.claude-3-5-sonnet-20240620-v1:0:200k
# Model ID: anthropic.claude-3-5-sonnet-20240620-v1:0
# Model ID: cohere.command-text-v14:7:4k
# Model ID: cohere.command-text-v14
# Model ID: cohere.command-r-v1:0
# Model ID: cohere.command-r-plus-v1:0
# Model ID: cohere.command-light-text-v14:7:4k
# Model ID: cohere.command-light-text-v14
# Model ID: cohere.embed-english-v3:0:512
# Model ID: cohere.embed-english-v3
# Model ID: cohere.embed-multilingual-v3:0:512
# Model ID: cohere.embed-multilingual-v3
# Model ID: cohere.rerank-v3-5:0
# Model ID: deepseek.r1-v1:0
# Model ID: meta.llama3-8b-instruct-v1:0
# Model ID: meta.llama3-70b-instruct-v1:0
# Model ID: meta.llama3-1-8b-instruct-v1:0:128k
# Model ID: meta.llama3-1-8b-instruct-v1:0
# Model ID: meta.llama3-1-70b-instruct-v1:0:128k
# Model ID: meta.llama3-1-70b-instruct-v1:0
# Model ID: meta.llama3-1-405b-instruct-v1:0
# Model ID: meta.llama3-2-11b-instruct-v1:0:128k
# Model ID: meta.llama3-2-11b-instruct-v1:0
# Model ID: meta.llama3-2-90b-instruct-v1:0:128k
# Model ID: meta.llama3-2-90b-instruct-v1:0
# Model ID: meta.llama3-2-1b-instruct-v1:0:128k
# Model ID: meta.llama3-2-1b-instruct-v1:0
# Model ID: meta.llama3-2-3b-instruct-v1:0:128k
# Model ID: meta.llama3-2-3b-instruct-v1:0
# Model ID: meta.llama3-3-70b-instruct-v1:0
# Model ID: mistral.mistral-7b-instruct-v0:2
# Model ID: mistral.mixtral-8x7b-instruct-v0:1
# Model ID: mistral.mistral-large-2402-v1:0
# Model ID: mistral.mistral-large-2407-v1:0
# Model ID: luma.ray-v2:0

# %% [markdown]
# Tester un appel à un LLM :

# %%
bedrock = session.client("bedrock-runtime")

# Prompt d'entrée pour le modèle Titan
prompt = {
    "inputText": "Tell me something interesting about neural networks."
}

# Appel au modèle
response = bedrock.invoke_model(
    modelId="amazon.titan-text-express-v1",
    body=bytes(str(prompt).replace("'", '"'), "utf-8"),
    contentType="application/json",
    accept="application/json"
)

# Affichage du résultat
print(response["body"].read().decode())
# Out:
# {"inputTextTokenCount":8,"results":[{"tokenCount":113,"outputText":"\nNeural networks are computer systems that are modeled after the human brain and can learn and adapt like humans. Neural networks are built from artificial neurons that can process information using mathematical operations. They are used in many applications, such as image recognition, natural language processing, and autonomous vehicles. Neural networks are trained using large amounts of data and can be used to make predictions or decisions. They are also used in robotics and medical imaging. Neural networks are complex systems that can be difficult to understand and train, but they have the potential to revolutionize many industries.","completionReason":"FINISH"}]}

# %% [markdown]
# # Connection avec la base de données (S3 et Redshift) :

# %%
pip install redshift-connector
# Out:
# Requirement already satisfied: redshift-connector in c:\users\zinii\anaconda3\lib\site-packages (2.1.5)
# Requirement already satisfied: scramp<1.5.0,>=1.2.0 in c:\users\zinii\anaconda3\lib\site-packages (from redshift-connector) (1.4.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zinii\appdata\roaming\python\python311\site-packages (from redshift-connector) (2024.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.7.0 in c:\users\zinii\anaconda3\lib\site-packages (from redshift-connector) (4.12.2)
# Requirement already satisfied: boto3<2.0.0,>=1.9.201 in c:\users\zinii\anaconda3\lib\site-packages (from redshift-connector) (1.36.11)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in c:\users\zinii\anaconda3\lib\site-packages (from redshift-connector) (2.31.0)
# Requirement already satisfied: lxml>=4.6.5 in c:\users\zinii\anaconda3\lib\site-packages (from redshift-connector) (4.9.3)
# Requirement already satisfied: botocore<2.0.0,>=1.12.201 in c:\users\zinii\anaconda3\lib\site-packages (from redshift-connector) (1.36.11)
# Requirement already satisfied: packaging in c:\users\zinii\anaconda3\lib\site-packages (from redshift-connector) (24.2)
# Requirement already satisfied: setuptools in c:\users\zinii\anaconda3\lib\site-packages (from redshift-connector) (68.0.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\zinii\anaconda3\lib\site-packages (from beautifulsoup4<5.0.0,>=4.7.0->redshift-connector) (2.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\zinii\anaconda3\lib\site-packages (from boto3<2.0.0,>=1.9.201->redshift-connector) (0.10.0)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in c:\users\zinii\anaconda3\lib\site-packages (from boto3<2.0.0,>=1.9.201->redshift-connector) (0.11.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\zinii\appdata\roaming\python\python311\site-packages (from botocore<2.0.0,>=1.12.201->redshift-connector) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\zinii\anaconda3\lib\site-packages (from botocore<2.0.0,>=1.12.201->redshift-connector) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zinii\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->redshift-connector) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zinii\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->redshift-connector) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zinii\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->redshift-connector) (2024.2.2)
# Requirement already satisfied: asn1crypto>=1.5.1 in c:\users\zinii\anaconda3\lib\site-packages (from scramp<1.5.0,>=1.2.0->redshift-connector) (1.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\zinii\appdata\roaming\python\python311\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.12.201->redshift-connector) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Vérifier que la connection marche :

# %%
import boto3

# Initialisation du client Redshift Data
client = boto3.client('redshift-data', region_name='us-west-2')

# Paramètres de connexion
database = 'dev'
workgroup_name = 'redshift-wg-hackathon'

# Requête de test
sql_query = 'SELECT current_date;'

try:
    response = client.execute_statement(
        Database=database,
        WorkgroupName=workgroup_name, 
        Sql=sql_query
    )
    print("✅ Connexion réussie !")
    print("Statement ID :", response["Id"])
except Exception as e:
    print(f"❌ Erreur de connexion : {e}")
# Out:
# ✅ Connexion réussie !
# Statement ID : a2ae7c98-66c7-4e43-89e8-a261a8d3dce0

# %%
import pandas as pd
import time

def run_sql_and_show(query):
    try:
        response = client.execute_statement(
            Database=database,
            WorkgroupName=workgroup_name,
            Sql=query
        )
        statement_id = response["Id"]

        while True:
            status = client.describe_statement(Id=statement_id)
            if status["Status"] in ["FINISHED", "FAILED", "ABORTED"]:
                break
            time.sleep(1)

        if status["Status"] == "FINISHED":
            results = client.get_statement_result(Id=statement_id)
            columns = [col["name"] for col in results["ColumnMetadata"]]
            rows = [
                [field.get("stringValue", "") for field in record]
                for record in results["Records"]
            ]
            df = pd.DataFrame(rows, columns=columns)
            display(df)  # joli tableau dans Jupyter
        else:
            print("❌ Erreur :", status["Error"])
    except Exception as e:
        print("❌ Exception :", e)
# Out:
# C:\Users\zinii\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# Ce code sert à :

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import boto3
import time

client = boto3.client('redshift-data', region_name='us-west-2')
database = 'dev'
workgroup_name = 'redshift-wg-hackathon'

def run_sql_and_fetch(query):
    try:
        response = client.execute_statement(
            Database=database,
            WorkgroupName=workgroup_name,
            Sql=query
        )
        statement_id = response["Id"]
        while True:
            status = client.describe_statement(Id=statement_id)
            if status["Status"] in ["FINISHED", "FAILED", "ABORTED"]:
                break
            time.sleep(1)

        if status["Status"] == "FINISHED":
            print("✅ Requête exécutée avec succès.")
        else:
            print("❌ Erreur :", status["Error"])
    except Exception as e:
        print("❌ Exception :", e)

# %% [markdown]
# Ce code sert à :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Nos tables dans Redshift :

# %% [markdown]
# Création de la table clients_database :

# %%
create_table = """
CREATE TABLE clients_database (
    Client_ID NUMERIC,
    Auto_Insurance_Contract NUMERIC,
    Health_Insurance_Contract NUMERIC,
    Home_Insurance_Contract NUMERIC,
    Life_Insurance_Contract NUMERIC,
    Coverage_Amount NUMERIC,
    Assurance_Cost_Per_Month NUMERIC,
    Creditworthiness VARCHAR(255),
    Claims_History_Count NUMERIC,
    Last_Reported_Claim_Type VARCHAR(255),
    Last_Reported_Claim_Date DATE,
    Last_Claim_Resolution_Type VARCHAR(255),
    Claim_Rate DECIMAL(10, 2),
    Customer_Tenure_Years NUMERIC,
    Is_Premium_Client NUMERIC,
    Health_History VARCHAR(255),
    Risk_Profile VARCHAR(255),
    Recent_Life_Event VARCHAR(255),
    Recent_Life_Event_Date DATE,
    Age NUMERIC,
    Annual_Income NUMERIC,
    Employment_Status VARCHAR(255),
    Has_Kids NUMERIC,
    Homeownership_Status VARCHAR(255),
    Type_of_Housing VARCHAR(255),
    Has_Car NUMERIC,
    Location VARCHAR(255),
    Primary_Transportation_Mode VARCHAR(255),
    Last_Interaction_Date DATE,
    Last_Contract_Change_Date NUMERIC,
    Last_Account_Update NUMERIC
);
"""

run_sql_and_fetch(create_table)
# Out:
# ✅ Requête exécutée avec succès.

# %% [markdown]
# Importer les données de notre fichier data_final.csv (stocké dans S3), dans notre table clients_database dans Redshift :

# %%
copy_query = """
COPY clients_database
FROM 's3://s3-bucket-eika/data_final.csv'
IAM_ROLE 'arn:aws:iam::485194702049:role/service-role/AmazonRedshift-CommandsAccessRole-20250405T172656'
FORMAT AS CSV
IGNOREHEADER 1
EMPTYASNULL
DATEFORMAT AS 'DD/MM/YYYY';
"""

run_sql_and_fetch(copy_query)
# Out:
# ✅ Requête exécutée avec succès.

# %% [markdown]
# Vérifier que ca a marché :

# %%
run_sql_and_show("SELECT * FROM clients_database order by client_id;")
# Out:
#      client_id auto_insurance_contract health_insurance_contract  \
# 0            1                       1                         0
# 1            2                       1                         1
# 2            3                       0                         1
# 3            4                       0                         1
# 4            5                       1                         1
# ...        ...                     ...                       ...
# 9995      9996                       1                         0
# 9996      9997                       0                         0
# 9997      9998                       0                         0
# 9998      9999                       1                         0
# 9999     10000                       1                         0
#
#      home_insurance_contract life_insurance_contract coverage_amount  \
# 0                          1                       1           52004
# 1                          0                       1           48660
# 2                          1                       0           42672
# 3                          1                       0           89407
# 4                          1                       0           92453
# ...                      ...                     ...             ...
# 9995                       0                       0           75208
# 9996                       1                       1           83216
# 9997                       1                       0           95967
# 9998                       1                       0           59336
# 9999                       1                       0           33774
#
#      assurance_cost_per_month creditworthiness claims_history_count  \
# 0                         225        Excellent                    0
# 1                         858        Excellent                    0
# 2                         259          Average                    4
# 3                         825             Poor                    0
# 4                         451        Excellent                    3
# ...                       ...              ...                  ...
# 9995                      933        Excellent                    4
# 9996                      940             Good                    2
# 9997                      403        Excellent                    4
# 9998                      151        Excellent                    0
# 9999                      535             Good                    3
#
#      last_reported_claim_type  ... employment_status has_kids  \
# 0                              ...        Unemployed        1
# 1                              ...        Unemployed        0
# 2                      Damage  ...            Remote        1
# 3                              ...            Remote        1
# 4                    Accident  ...        Unemployed        1
# ...                       ...  ...               ...      ...
# 9995                 Accident  ...            Hybrid        0
# 9996                    Theft  ...        Unemployed        1
# 9997                    Theft  ...        Unemployed        1
# 9998                           ...        Unemployed        0
# 9999                 Accident  ...            Remote        0
#
#      homeownership_status     type_of_housing has_car  location  \
# 0                     Own           Apartment       1     Urban
# 1                     Own           Apartment       0     Urban
# 2                     Own  Single-family home       0     Urban
# 3                     Own           Apartment       0     Urban
# 4                     Own           Townhouse       0     Urban
# ...                   ...                 ...     ...       ...
# 9995                  Own           Townhouse       0  Suburban
# 9996                  Own  Single-family home       0     Urban
# 9997                  Own  Single-family home       0     Urban
# 9998                  Own  Single-family home       0     Urban
# 9999                 Rent  Single-family home       0  Suburban
#
#      primary_transportation_mode last_interaction_date  \
# 0          Public transportation            2024-02-07
# 1                         Biking            2024-02-17
# 2                            Car            2023-04-06
# 3                            Car            2024-06-14
# 4                        Walking            2025-02-15
# ...                          ...                   ...
# 9995                         Car            2023-05-08
# 9996                      Biking            2023-06-20
# 9997       Public transportation            2024-10-02
# 9998                      Biking            2023-12-26
# 9999       Public transportation            2024-03-12
#
#      last_contract_change_date last_account_update
# 0                          212                   0
# 1                          280                   0
# 2                          153                   0
# 3                          459                   0
# 4                          383                   0
# ...                        ...                 ...
# 9995                       393                   0
# 9996                       119                   0
# 9997                       176                   0
# 9998                       150                   0
# 9999                       342                   0
#
# [10000 rows x 31 columns]

# %%
run_sql_and_fetch("""
ALTER TABLE clients_database DROP COLUMN client_id;

ALTER TABLE clients_database ADD COLUMN client_id NUMBER;

UPDATE clients_database
SET client_id = sub.new_id
FROM (
    SELECT ROW_NUMBER() OVER (ORDER BY true) AS new_id,
           ctid
    FROM clients_database
) AS sub
WHERE clients_database.ctid = sub.ctid;
""")
# Out:
# ❌ Erreur : ERROR: cannot drop sortkey column "client_id"

# %%
run_sql_and_show("""
SELECT tablename
FROM pg_table_def
WHERE schemaname = 'public'
GROUP BY tablename
ORDER BY tablename;
""")
# Out:
#           tablename
# 0  clients_database

# %%
run_sql_and_fetch("DROP TABLE IF EXISTS clients_database2;")
# Out:
# ✅ Requête exécutée avec succès.

# %%
import boto3
import time

# Config Redshift
redshift_client = boto3.client("redshift-data", region_name="us-west-2")
DATABASE = "dev"
WORKGROUP = "redshift-wg-hackathon"

# Commande SQL à exécuter
sql_query = "GRANT SELECT ON ALL TABLES IN SCHEMA public TO PUBLIC;"

# Envoi de la requête
response = redshift_client.execute_statement(
    Database=DATABASE,
    WorkgroupName=WORKGROUP,
    Sql=sql_query
)

# Attente du résultat
statement_id = response['Id']
print(f"Statement ID: {statement_id}")

# Attendre l'exécution
while True:
    status = redshift_client.describe_statement(Id=statement_id)["Status"]
    if status in ["FINISHED", "FAILED", "ABORTED"]:
        break
    time.sleep(2)

# Vérification du statut
if status == "FINISHED":
    print("Droits SQL GRANT exécutés avec succès.")
else:
    print(f"Erreur durant l'exécution: {status}")
# Out:
# Statement ID: b32a0b9c-2c73-404d-9653-df08a7f229be
# ✅ Droits SQL GRANT exécutés avec succès.
